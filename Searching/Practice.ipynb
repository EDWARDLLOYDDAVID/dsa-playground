# %%
a = 5

l = a / 2
l1 = a // 2
l2 = a % 2

print(l,l1,l2)
# Out:
# 2.5 2 1

# %%
X = [7, 0, 3, 5, 2, 8,5,1]
n = len(X)
for i in range(n-1):
    isSwapped = False
    for j in range(n-i-1):
        if(X[j] > X[j+1]):
            X[j], X[j+1] = X[j+1], X[j]
            isSwapped = True
    if not isSwapped:
        break

def binary_search(arr, target):
    n = len(arr)
    LB = 0
    UB = n-1

    mid = (LB + UB) // 2

# %%
a =5 
b = a/2
print(int(b))
# Out:
# 2

# %%
X = [1,2,3,4,5,6,7,8,9]

T = 111

lb = 0
up = len(X)-1

while lb <= up:
    mod = (lb+up)//2

    if X[mod] == T:
        print("Found at index : ", mod)
        break
    else:
        if(X[mod] < T):
            lb = mod + 1
        else: 
            up = mod - 1

# %%
L = [1,2,4,8,16,32]

mid = len(L) // 2

print(mid, L[mid])
# Out:
# 3 8
